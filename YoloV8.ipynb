# %%
# !pip install torch torchvision pytorch-lightning opencv-python
# !pip install torch torchvision pytorch-lightning opencv-python
# !pip install ultralytics
# !pip install -e ultralytics
# !pip install ultralytics yolov8
# Out:
# ...
# ERROR: ultralytics is not a valid editable requirement. It should either be a path to a local project or a VCS URL (beginning with bzr+http, bzr+https, bzr+ssh, bzr+sftp, bzr+ftp, bzr+lp, bzr+file, git+http, git+https, git+ssh, git+git, git+file, hg+file, hg+http, hg+https, hg+ssh, hg+static-http, svn+ssh, svn+http, svn+https, svn+svn, svn+file).
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3hrZt70RZORDEChoimFo")
project = rf.workspace("lolo-0fyrg").project("emotions-classification-j8ezl")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.11, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to emotions-Classification-1 in yolov8:: 100%|██████████| 2405/2405 [00:00<00:00, 11099.78it/s]

# %%
# !git clone https://github.com/ultralytics/ultralytics
# !cd ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 25254, done.
# remote: Counting objects: 100% (721/721), done.
# remote: Compressing objects: 100% (487/487), done.
# remote: Total 25254 (delta 439), reused 443 (delta 230), pack-reused 24533
# Receiving objects: 100% (25254/25254), 15.04 MiB | 25.41 MiB/s, done.
# Resolving deltas: 100% (17755/17755), done.

# %%
# !yolo task=detect \
  mode=train \
  model=yolov8s.pt \
  data='https://app.roboflow.com/ds/iDv7PPoRiD?key=LWkw5i4UY4' \
  epochs=50 \
  imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 259MB/s]
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=val \
model=/content/runs/detect/train/weights/best.pt \
data=/content/datasets/iDv7PPoRiD/data.yaml
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127906 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/iDv7PPoRiD/valid/labels.cache... 239 images, 0 backgrounds, 0 corrupt: 100% 239/239 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 15/15 [00:10<00:00,  1.42it/s]
#                    all        239       1825      0.406       0.49      0.375      0.251
#                  angry        239         44      0.368      0.773      0.492      0.419
#                   fear        239         44      0.313      0.727      0.363      0.318
#                  happy        239         49      0.349      0.429      0.362      0.211
#                neutral        239        538       0.47      0.444      0.389      0.215
#                    sad        239        544      0.401      0.175       0.21       0.11
# ...

# %%
# !yolo task=detect \
mode=predict \
model=/content/runs/detect/train/weights/best.pt \
conf=0.25 \
source=/content/datasets/iDv7PPoRiD/test/images
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127906 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/120 /content/datasets/iDv7PPoRiD/test/images/PrivateTest_10131363_jpg.rf.0107254073b590a894abd5872749d721.jpg: 640x640 1 angry, 15.9ms
# image 2/120 /content/datasets/iDv7PPoRiD/test/images/PrivateTest_1054527_jpg.rf.1c7ec340237f74f61ff15fe7c07c0bc5.jpg: 640x640 1 angry, 16.1ms
# image 3/120 /content/datasets/iDv7PPoRiD/test/images/PrivateTest_12065785_jpg.rf.83c6aaf621dde26ebfe99beb8a8dd838.jpg: 640x640 1 fear, 15.9ms
# image 4/120 /content/datasets/iDv7PPoRiD/test/images/PrivateTest_12191716_jpg.rf.bd15dd816e01d63ea8e9018e09657b2b.jpg: 640x640 1 angry, 15.9ms
# image 5/120 /content/datasets/iDv7PPoRiD/test/images/PrivateTest_12641070_jpg.rf.9003bc6bd9c1fa9fea0f204695f008bf.jpg: 640x640 15 surprises, 15.9ms
# ...

# %%
# !zip -r ultralytics.zip /content/ultralytics/
# Out:
#   adding: content/ultralytics/ (stored 0%)
#   adding: content/ultralytics/tests/ (stored 0%)
#   adding: content/ultralytics/tests/test_explorer.py (deflated 71%)
#   adding: content/ultralytics/tests/test_engine.py (deflated 78%)
#   adding: content/ultralytics/tests/test_python.py (deflated 67%)
#   adding: content/ultralytics/tests/test_integrations.py (deflated 69%)
#   adding: content/ultralytics/tests/test_cuda.py (deflated 68%)
#   adding: content/ultralytics/tests/conftest.py (deflated 59%)
#   adding: content/ultralytics/tests/test_exports.py (deflated 78%)
#   adding: content/ultralytics/tests/test_cli.py (deflated 66%)
#   adding: content/ultralytics/tests/__init__.py (deflated 40%)
#   adding: content/ultralytics/.gitignore (deflated 49%)
#   adding: content/ultralytics/README.zh-CN.md (deflated 79%)
#   adding: content/ultralytics/README.md (deflated 82%)
#   adding: content/ultralytics/ultralytics/ (stored 0%)
# ...

# %%
# !zip -r run_AI_yolo.zip /content/runs/
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/R_curve.png (deflated 8%)
#   adding: content/runs/detect/train/F1_curve.png (deflated 9%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train/results.png (deflated 7%)
#   adding: content/runs/detect/train/confusion_matrix_normalized.png (deflated 21%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 12%)
#   adding: content/runs/detect/train/train_batch2121.jpg (deflated 13%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 24%)
#   adding: content/runs/detect/train/labels.jpg (deflated 27%)
#   adding: content/runs/detect/train/P_curve.png (deflated 5%)
# ...

# %%
# !zip -r emotions-Classification_yolo.zip /content/emotions-Classification-1/
# Out:
#   adding: content/emotions-Classification-1/ (stored 0%)
#   adding: content/emotions-Classification-1/test/ (stored 0%)
#   adding: content/emotions-Classification-1/test/labels/ (stored 0%)
#   adding: content/emotions-Classification-1/test/labels/Training_1938799_jpg.rf.d62afc58232450323cf804bdcdbc1ebb.txt (deflated 75%)
#   adding: content/emotions-Classification-1/test/labels/Training_980544_jpg.rf.34628310090a8598112169bb3a26310d.txt (deflated 78%)
#   adding: content/emotions-Classification-1/test/labels/Training_3009686_jpg.rf.9fe5043d3b4805cb4c43d01d297a65d6.txt (deflated 69%)
#   adding: content/emotions-Classification-1/test/labels/PrivateTest_10131363_jpg.rf.0107254073b590a894abd5872749d721.txt (deflated 61%)
#   adding: content/emotions-Classification-1/test/labels/Training_64796_jpg.rf.9003221b8b15342106f825e9158565b7.txt (deflated 79%)
#   adding: content/emotions-Classification-1/test/labels/Training_1214649_jpg.rf.f3280db1f9cb0110009598c5e004ab03.txt (deflated 53%)
# ...
